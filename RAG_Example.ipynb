# %% [markdown]
# # RAG example
#
# ## 🚀 Explicación del código
# 1. Carga documentos desde un archivo de texto (documento.txt).
# 2. Divide el texto en fragmentos para mejor indexación.
# 3. Genera embeddings usando sentence-transformers/all-MiniLM-L6-v2.
# 4. Almacena los embeddings en FAISS para búsquedas rápidas.
# 5. Usa Mistral-7B para generar respuestas en base a los documentos recuperados.

# %%
import os
from langchain_community.vectorstores import Chroma
from langchain_community.llms import HuggingFaceEndpoint
from langchain.chains import RetrievalQA
from langchain.chains.question_answering import load_qa_chain
from langchain_community.document_loaders import TextLoader
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from transformers import pipeline

# %%
# Función para cargar y dividir documentos
def load_and_split_documents(folder_path):
    print('En load_and_split_documents')
    text_splitter = CharacterTextSplitter(chunk_size=100, chunk_overlap=50)
    documents = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".txt"):
            loader = TextLoader(os.path.join(folder_path, file_name))
            documents.extend(text_splitter.split_documents(loader.load()))
    return documents

# %%
# Crear embeddings y almacenar en ChromaDB (modelo más potente)
def create_chroma_index(docs):
    model_name = "sentence-transformers/all-mpnet-base-v2"  # Modelo de embeddings más potente
    embeddings = HuggingFaceEmbeddings(model_name=model_name)
    return Chroma.from_documents(docs, embedding=embeddings)

# %%
def setup_llm():
    print('Cargando modelo en local...')
    return pipeline("text2text-generation", model="google/flan-t5-large")

# %%
def ask_rag(query, vector_store, llm):
    print('En ask_rag')
    retriever = vector_store.as_retriever(search_type="mmr", search_kwargs={"k": 3, "fetch_k": 5})
    docs = retriever.invoke(query)

    # Limitar el contexto para evitar entradas muy largas
    context = " ".join([doc.page_content for doc in docs])
    prompt = f"Context: {context}\n\nQuestion: {query}\n\nAnswer:"
    print('-----------')
    print("Prompt enviado al modelo:", prompt)  # Depuración
    print('-----------')
    # Ejecutar el modelo en local
    respuesta = llm(prompt, max_new_tokens=240, temperature=0.5, do_sample=True)
    #print(f'Respuesta RAW LLM: {respuesta}')
    return respuesta[0]['generated_text']

# %%
print('Ejecutando MAIN')
# Cargar documentos de la carpeta 'documentos'
documents = load_and_split_documents("documentos")

if not documents:
    raise ValueError("No se encontraron documentos para procesar.")

# Crear índice ChromaDB
vector_store = create_chroma_index(documents)

# Configurar el modelo LLM
llm = setup_llm()

print("RAG configurado y listo para consultas")

# Ejemplos de uso del RAG
preguntas = [
    "What happened during the French Revolution?",
    "What is the main equation of relativity?",
    "What is artificial intelligence?",
    "What are the principles of existentialism?",
    "What are the effects of climate change?",
    "Who is Alain Sanchez Gonzalez?",
    "What do you know about Denia Peña Estilismo?"
]

for pregunta in preguntas:
    print('************************************************')
    print(f'Pregunta: {pregunta}')
    respuesta = ask_rag(pregunta, vector_store, llm)
    print(f'Respuesta: {respuesta}')
    print('************************************************')
# Out:
# Ejecutando MAIN
# En load_and_split_documents
# Cargando modelo en local...
# RAG configurado y listo para consultas
# ************************************************
# Pregunta: What happened during the French Revolution?
# En ask_rag
# -----------
# Prompt enviado al modelo: Context: The French Revolution was a social and political conflict that began in 1789 in France. It led to the fall of the monarchy and the establishment of the First Republic, influencing many other revolutions around the world. The French Revolution was a social and political conflict that began in 1789 in France. It led to the fall of the monarchy and the establishment of the First Republic, influencing many other revolutions around the world. The French Revolution was a social and political conflict that began in 1789 in France. It led to the fall of the monarchy and the establishment of the First Republic, influencing many other revolutions around the world.
#
# Question: What happened during the French Revolution?
#
# Answer:
# -----------
# Respuesta: The French Revolution was a social and political conflict that began in 1789 in France. It led to the fall of the monarchy and the establishment of the First Republic, influencing many other revolutions around the world.
# ************************************************
# ************************************************
# Pregunta: What is the main equation of relativity?
# En ask_rag
# -----------
# Prompt enviado al modelo: Context: Einstein's theory of relativity transformed our understanding of space and time. His most famous equation, E=mc^2, shows the relationship between energy and mass. Einstein's theory of relativity transformed our understanding of space and time. His most famous equation, E=mc^2, shows the relationship between energy and mass. Einstein's theory of relativity transformed our understanding of space and time. His most famous equation, E=mc^2, shows the relationship between energy and mass.
#
# Question: What is the main equation of relativity?
#
# Answer:
# -----------
# Respuesta: E=mc2
# ************************************************
# ************************************************
# Pregunta: What is artificial intelligence?
# En ask_rag
# -----------
# Prompt enviado al modelo: Context: Artificial intelligence (AI) is a field of computer science that seeks to create systems capable of performing tasks that require human intelligence, such as speech recognition, computer vision and machine learning. Artificial intelligence (AI) is a field of computer science that seeks to create systems capable of performing tasks that require human intelligence, such as speech recognition, computer vision and machine learning. Artificial intelligence (AI) is a field of computer science that seeks to create systems capable of performing tasks that require human intelligence, such as speech recognition, computer vision and machine learning.
#
# Question: What is artificial intelligence?
#
# Answer:
# -----------
# Respuesta: field of computer science
# ************************************************
# ************************************************
# Pregunta: What are the principles of existentialism?
# En ask_rag
# -----------
# Prompt enviado al modelo: Context: Existentialism is a philosophical current that emphasizes individual freedom, responsibility and the personal meaning of life. Philosophers such as Sartre and Heidegger were key figures in its development. Existentialism is a philosophical current that emphasizes individual freedom, responsibility and the personal meaning of life. Philosophers such as Sartre and Heidegger were key figures in its development. Existentialism is a philosophical current that emphasizes individual freedom, responsibility and the personal meaning of life. Philosophers such as Sartre and Heidegger were key figures in its development.
#
# Question: What are the principles of existentialism?
#
# Answer:
# -----------
# Respuesta: individual freedom, responsibility and the personal meaning of life
# ************************************************
# ************************************************
# Pregunta: What are the effects of climate change?
# En ask_rag
# -----------
# Prompt enviado al modelo: Context: Climate change is a global problem caused by the increase in greenhouse gases. Its effects include rising temperatures, melting of the poles and extreme weather events. Climate change is a global problem caused by the increase in greenhouse gases. Its effects include rising temperatures, melting of the poles and extreme weather events. Climate change is a global problem caused by the increase in greenhouse gases. Its effects include rising temperatures, melting of the poles and extreme weather events.
#
# Question: What are the effects of climate change?
#
# Answer:
# -----------
# Respuesta: rising temperatures, melting of the poles and extreme weather events
# ************************************************
# ************************************************
# Pregunta: Who is Alain Sanchez Gonzalez?
# En ask_rag
# -----------
# Prompt enviado al modelo: Context: Alain Sánchez González is a data scientist with more than 14 years of experience in machine learning and deep learning, specialized in developing scalable and high-impact solutions in data analytics. With a solid background in academic research and practical application, I have designed and implemented advanced models to solve complex problems in cybersecurity, natural language processing and computer vision. Passionate about arAficial intelligence, I approach each project with rigor, innovation and an excellence-oriented approach. Alain Sánchez González is a data scientist with more than 14 years of experience in machine learning and deep learning, specialized in developing scalable and high-impact solutions in data analytics. With a solid background in academic research and practical application, I have designed and implemented advanced models to solve complex problems in cybersecurity, natural language processing and computer vision. Passionate about arAficial intelligence, I approach each project with rigor, innovation and an excellence-oriented approach. Alain Sánchez González is a data scientist with more than 14 years of experience in machine learning and deep learning, specialized in developing scalable and high-impact solutions in data analytics. With a solid background in academic research and practical application, I have designed and implemented advanced models to solve complex problems in cybersecurity, natural language processing and computer vision. Passionate about arAficial intelligence, I approach each project with rigor, innovation and an excellence-oriented approach.
#
# Question: Who is Alain Sanchez Gonzalez?
#
# Answer:
# -----------
# Respuesta: data scientist
# ************************************************
# ************************************************
# Pregunta: What do you know about Denia Peña Estilismo?
# En ask_rag
# -----------
# Prompt enviado al modelo: Context: Denia Peña Estilismo is a hair and beauty salon located in the heart of Bilbao that offers exclusive and personalized hairdressing services. We pride ourselves in offering the best beauty treatments and personalized advice to make you feel and look better than ever. Our commitment to quality and sustainability is reflected in our products and the way we use them. We are also specialists in the curly method, cuts, highlights and updos. Whatever your hair and style, we will advise you to find the look you are looking for. Denia Peña Estilismo is a hair and beauty salon located in the heart of Bilbao that offers exclusive and personalized hairdressing services. We pride ourselves in offering the best beauty treatments and personalized advice to make you feel and look better than ever. Our commitment to quality and sustainability is reflected in our products and the way we use them. We are also specialists in the curly method, cuts, highlights and updos. Whatever your hair and style, we will advise you to find the look you are looking for. Denia Peña Estilismo is a hair and beauty salon located in the heart of Bilbao that offers exclusive and personalized hairdressing services. We pride ourselves in offering the best beauty treatments and personalized advice to make you feel and look better than ever. Our commitment to quality and sustainability is reflected in our products and the way we use them. We are also specialists in the curly method, cuts, highlights and updos. Whatever your hair and style, we will advise you to find the look you are looking for.
#
# Question: What do you know about Denia Peña Estilismo?
#
# Answer:
# -----------
# Respuesta: hair and beauty salon located in the heart of Bilbao that offers exclusive and personalized hairdressing services
# ************************************************
